# %%
# !pip install -r requirements-colab.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.6/766.6 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 88.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 37.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 112.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# Rule based target_text

# %%
# !python tablellm/scripts/generate_tablellm_output_text.py \
  --input llama/outputs/text_only_rompt/llama_tabular_outputs_with_targets.csv \
  --output tablellm/outputs/llama_tabular_outputs_with_tablellm.csv \
  --prompt-column input_text \
  --output-column output_text \
  --tablellm-prompt original \
  --load-4bit \
  --max-rows 10
# Out:
# 2026-06-29 22:43:22.115915: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors.index.json: 23.9kB [00:00, 6.25MB/s]
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:00<?, ?B/s]
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
#
#
#
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:00<?, ?B/s]
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:00<?, ?B/s]
#
#
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
#
#
#
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:00<?, ?B/s]
# ...

# %%
# !python tablellm/scripts/evaluate_tablellm_cv.py \
  --input tablellm/outputs/llama_tabular_outputs_with_tablellm.csv \
  --prompt-column input_text \
  --target-column target_text \
  --prediction-column output_text \
  --output-dir tablellm/outputs/tablellm_silver_eval
# Out:
#    fold  rouge_l_f1  text_similarity  format_score  cautious_language  safety_score
#       1    0.107701         0.133351         0.250                0.5           0.0
#       2    0.096872         0.089751         0.375                0.0           0.5
#       3    0.115464         0.129433         0.375                0.0           0.5
#       4    0.113005         0.114319         0.625                0.5           1.0
#       5    0.105393         0.098911         0.250                0.0           0.0
# overall    0.107687         0.113153         0.375                0.2           0.4
#
# Wrote detailed results to: tablellm/outputs/tablellm_silver_eval/tablellm_cv_results.csv
# Wrote summary to: tablellm/outputs/tablellm_silver_eval/tablellm_cv_summary.csv
# Wrote chart to: tablellm/outputs/tablellm_silver_eval/tablellm_cv_fold_scores.png
# Wrote chart to: tablellm/outputs/tablellm_silver_eval/tablellm_cv_operation_scores.png

# %% [markdown]
# Silver standard generated_text column

# %%
# !python tablellm/scripts/generate_tablellm_output_text.py \
  --input data/lab_summaries_export.csv \
  --output tablellm/outputs/tablellm_with_llama_silver.csv \
  --prompt-column prompt \
  --output-column output_text \
  --tablellm-prompt original \
  --load-4bit \
  --max-rows 10
# Out:
# 2026-06-29 23:02:02.617098: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading checkpoint shards: 100% 4/4 [01:05<00:00, 16.49s/it]
# Processed row 0 (1 generated, 0 skipped)
# Processed row 1 (2 generated, 0 skipped)
# Processed row 2 (3 generated, 0 skipped)
# Processed row 3 (4 generated, 0 skipped)
# Processed row 4 (5 generated, 0 skipped)
# Processed row 5 (6 generated, 0 skipped)
# Processed row 6 (7 generated, 0 skipped)
# Processed row 7 (8 generated, 0 skipped)
# Processed row 8 (9 generated, 0 skipped)
# Processed row 9 (10 generated, 0 skipped)
#
# Generated rows: 10
# Skipped rows: 0
# Wrote: tablellm/outputs/tablellm_with_llama_silver.csv

# %%
# !python tablellm/scripts/evaluate_tablellm_cv.py \
  --input tablellm/outputs/tablellm_with_llama_silver.csv \
  --prompt-column prompt \
  --target-column generated_text \
  --prediction-column output_text \
  --output-dir tablellm/outputs/tablellm_llama_silver_eval
# Out:
#    fold  rouge_l_f1  text_similarity  format_score  cautious_language  safety_score
#       1    0.447768         0.345010      0.660714                1.0           1.0
#       2    0.149591         0.039550      0.535714                1.0           1.0
#       3    0.169645         0.026918      0.500000                1.0           1.0
#       4    0.140220         0.080687      0.517241                1.0           1.0
#       5    0.143079         0.021134      0.416667                0.5           1.0
# overall    0.210061         0.102660      0.526067                0.9           1.0
#
# Wrote detailed results to: tablellm/outputs/tablellm_llama_silver_eval/tablellm_cv_results.csv
# Wrote summary to: tablellm/outputs/tablellm_llama_silver_eval/tablellm_cv_summary.csv
# Wrote chart to: tablellm/outputs/tablellm_llama_silver_eval/tablellm_cv_fold_scores.png
# Wrote chart to: tablellm/outputs/tablellm_llama_silver_eval/tablellm_cv_operation_scores.png
